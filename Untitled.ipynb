# %%
import os
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

class BallDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform
        self.images = [img for img in os.listdir(image_dir) if img.endswith('.png')]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.images[idx])
        mask_path = os.path.join(self.mask_dir, self.images[idx])
        
        image = Image.open(img_path).convert("RGB")
        mask = Image.open(mask_path).convert("L")  # Convert masks to grayscale
        
        if self.transform:
            image = self.transform(image)
            mask = self.transform(mask)
            
        return image, mask

# Example usage:
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
])

# Adjust the paths according to your directory structure
dataset = BallDataset(
    image_dir=r'C:\Users\91939\Desktop\CHANDU\ANN-SEM1\SS24_AssignmentFinal\SportsBallsSmall\Train', 
    mask_dir=r'C:\Users\91939\Desktop\CHANDU\ANN-SEM1\SS24_AssignmentFinal\SportsBallsSmall\train_masks', 
    transform=transform
)

dataloader = DataLoader(dataset, batch_size=6, shuffle=True)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

def double_conv(in_channels, out_channels):
    return nn.Sequential(
        nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1, bias=False),
        nn.BatchNorm2d(out_channels),
        nn.ReLU(inplace=True),
        nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1, bias=False),
        nn.BatchNorm2d(out_channels),
        nn.ReLU(inplace=True),
    )

class UNet(nn.Module):
    def __init__(self, in_channels=3, out_channels=1, features=[64, 128, 256, 512]):
        super(UNet, self).__init__()
        self.encoder = nn.ModuleList(
            [double_conv(in_channels, features[0])] + 
            [double_conv(features[i], features[i+1]) for i in range(len(features) - 1)]
        )
        self.decoder = nn.ModuleList(
            [nn.ConvTranspose2d(features[i] * 2, features[i], kernel_size=2, stride=2) for i in range(len(features) - 1, -1, -1)] +
            [double_conv(features[i] * 2, features[i]) for i in range(len(features) - 1, -1, -1)]
        )
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.bottleneck = double_conv(features[-1], features[-1] * 2)
        self.final_conv = nn.Conv2d(features[0], out_channels, kernel_size=1)

    def forward(self, x):
        skip_connections = []

        for down in self.encoder:
            x = down(x)
            skip_connections.append(x)
            x = self.pool(x)

        x = self.bottleneck(x)
        skip_connections = skip_connections[::-1]

        for idx in range(0, len(self.decoder), 2):
            x = self.decoder[idx](x)
            skip_connection = skip_connections[idx // 2]
            if x.shape != skip_connection.shape:
                x = F.interpolate(x, size=skip_connection.shape[2:])
            x = torch.cat((skip_connection, x), dim=1)
            x = self.decoder[idx + 1](x)

        return self.final_conv(x)

# Example usage:
model = UNet(in_channels=3, out_channels=1)

# %%
model
# Out:
# UNet(
#   (encoder): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (2): Sequential(
# ...

# %%
import torch.optim as optim

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# %%
import torch
import torch.nn as nn
from torch.cuda.amp import autocast, GradScaler

# Define the number of epochs and device
num_epochs = 5
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Move model and criterion to the device
model.to(device)
criterion.to(device)

# Define the optimizer and scaler for mixed precision
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
scaler = GradScaler()

# Update the DataLoader to use multiple workers
dataloader = DataLoader(dataset, batch_size=6, shuffle=True, num_workers=4, pin_memory=True)

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0

    for images, masks in dataloader:
        images, masks = images.to(device), masks.to(device)

        optimizer.zero_grad()
        
        with autocast():
            outputs = model(images)
            loss = criterion(outputs, masks)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()

    avg_loss = running_loss / len(dataloader)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}")

# %%
import pandas as pd
import numpy as np
from PIL import Image
import os

def generate_masks(image_dir, label_csv, output_dir):
    # Load the labels
    df = pd.read_csv(label_csv)
    
    # Create the output directory if it does not exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Create a mask for each image
    for idx, row in df.iterrows():
        img_filename = row['filename']
        label = row['label']

         # Append ".png" to the filename
        img_filename_with_extension = img_filename + ".png"
        
        # Load the image
        img_path = os.path.join(image_dir, img_filename_with_extension)
        image = Image.open(img_path).convert('RGB')
        
        # Create a binary mask based on the label
        # For simplicity, we'll create a mask where pixels are set to 1 if they belong to the ball
        # You'll need to implement an actual segmentation mask generation logic here
        
        # Create a blank mask with the same size as the image
        mask = Image.new('L', image.size, 0)
        mask_data = np.array(mask)
        
        # Simulate a mask based on the label
        # Example: assuming you can determine the region of the ball
        # For demonstration purposes, we'll just draw a simple filled circle in the mask
        
        # Example of simple mask generation (replace with your actual mask logic)
        # This is just for illustrative purposes and won't actually work for your case
        from PIL import ImageDraw
        draw = ImageDraw.Draw(mask)
        draw.ellipse((10, 10, 50, 50), fill=255)  # Dummy mask (change this to your logic)

        # Save the mask
        mask_path = os.path.join(output_dir, img_filename_with_extension)
        mask.save(mask_path)
        
        print(f"Generated mask for {img_filename}")

# Example usage
generate_masks(r'C:\Users\91939\Desktop\CHANDU\ANN-SEM1\SS24_AssignmentFinal\SportBallsSmall\Train', r'C:\Users\91939\Desktop\CHANDU\ANN-SEM1\SS24_AssignmentFinal\SportBallsSmall\train_labels.csv', r"C:\Users\91939\Desktop\CHANDU\ANN-SEM1\SS24_AssignmentFinal\SportBallsSmall\train_segmented_masks")
